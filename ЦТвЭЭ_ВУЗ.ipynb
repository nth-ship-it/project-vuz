# %% [markdown]
# <a href="https://colab.research.google.com/github/nth-ship-it/project-vuz/blob/main/%D0%A6%D0%A2%D0%B2%D0%AD%D0%AD_%D0%92%D0%A3%D0%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Заголовок номер 1

# %% [markdown]
# Список бригады:
#
# *   Васильев Степан
# *   Милютин Егор
# *   Москов Михаил

# %% [markdown]
# Рисунок: Логотип НГТУ НЭТИ
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | A | B | C |
# |---|---|---|
# | 11 | 22 | 33 |
# | 1000 | 250 | -50 |

# %% [markdown]
# [Ссылка на видос индуса, который все обьясняет](https://www.youtube.com/watch?v=UQaTbJThjmM)

# %% [markdown]
# [Ссылка на руководство по Markdown](https://www.markdownguide.org/)

# %% [markdown]
# Проверка “Save and pin revision”
